# %% [markdown]
# # Province Gender Available Twitter Data - Monthly Topics

# %%
import gzip
import json
import pandas as pd
import re
from collections import Counter
from nltk.corpus import stopwords

# %% [markdown]
# ## Read Data from Gzip

# %%
with gzip.open("province_gender_available_metadata_added-220522_combined.txt.gz", "rb") as f:
    users = f.readlines()
    
for i in range(len(users)):
    users[i] = json.loads(users[i].decode("utf-8"))

# %% [markdown]
# ## Create DataFrame

# %%
df = pd.DataFrame(users)

# %%
df.shape
# Out:
# (364570, 15)

# %%
df.head(3)
# Out:
#              location                                        description  \
# 0      adana, türkiye  nefes alıyorsak hala bir umut var demektir. fa...
# 1  çanakkale, türkiye                                           emu-ı.t.
# 2  gaziantep, türkiye                                        galatasaray
#
#         name      screen_name               id_str  \
# 0        ali       real107171  1158321552129187840
# 1      yahya     yahyahlvoglu           1702767367
# 2  can altay  canalta29003836  1161346708883816448
#
#                        created_at                         province_codes  \
# 0  Mon Aug 05 10:19:13 +0000 2019   [{'source': 'location', 'pcode': 1}]
# 1  Mon Aug 26 19:26:40 +0000 2013  [{'source': 'location', 'pcode': 17}]
# 2  Tue Aug 13 18:40:06 +0000 2019  [{'source': 'location', 'pcode': 27}]
#
#                                              genders  \
# 0             [{'source': 'name', 'gender': 'male'}]
# 1  [{'source': 'name', 'gender': 'male'}, {'sourc...
# 2             [{'source': 'name', 'gender': 'male'}]
#
#                                            following  \
# 0  [126571977, 1974277500, 2784055768, 1097258683...
# 1  [2390341533, 767691353144827906, 259925559, 34...
# 2  [1401495806142734337, 1245674500039102464, 983...
#
#                                            followers  \
# 0  [721395301274238976, 1070013184344510464, 1510...
# 1  [2390341533, 957649186064949248, 1120358786097...
# 2  [1401495806142734337, 1290700623801876487, 124...
#
#                                               tweets followers_count  \
# 0  [{'twt_id_str': '1173723046072475649', 'twt_tx...               3
# 1  [{'ref_twt_id_str': '1421381248400994307', 're...             270
# 2  [{'twt_id_str': '1269646996362670081', 'twt_tx...              10
#
#   following_count downloaded                                       pp
# 0               9     220318  1158321652691886080/VJc3tvbT_normal.jpg
# 1             205     220318  1430022847607488516/KLhPDuBE_normal.jpg
# 2              13     220318  1228998578703683585/Uq1zinZ-_normal.jpg

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364570 entries, 0 to 364569
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   location         364570 non-null  object
#  1   description      364570 non-null  object
#  2   name             364570 non-null  object
#  3   screen_name      364570 non-null  object
#  4   id_str           364570 non-null  object
#  5   created_at       364570 non-null  object
#  6   province_codes   364570 non-null  object
#  7   genders          364570 non-null  object
#  8   following        364570 non-null  object
#  9   followers        364570 non-null  object
#  10  tweets           364570 non-null  object
#  11  followers_count  364570 non-null  object
#  12  following_count  364570 non-null  object
#  13  downloaded       364570 non-null  object
#  14  pp               364570 non-null  object
# dtypes: object(15)
# memory usage: 41.7+ MB

# %% [markdown]
# ## Filter for Favorites

# %%
# Filter "tweets" for favorite tweets
for i in range(len(df)):
    df.loc[i, "tweets"] = [tweet for tweet in df.loc[i, "tweets"] if tweet["type"] == "fav"]

# %%
fav_tweet_count = 0

for tweet_list in df["tweets"]:
    fav_tweet_count += len(tweet_list)
    
print(f"Favorite tweet count: {fav_tweet_count}")
# Out:
# Favorite tweet count: 11068724

# %%
fav_tweet_count_2021 = 0

for tweet_list in df["tweets"]:
    for tweet in tweet_list:
        if tweet["twt_date"][:2] == '21':
            fav_tweet_count_2021 += 1
            
print(f"Favorite tweet count for 2021: {fav_tweet_count_2021}")
# Out:
# Favorite tweet count for 2021: 2395175

# %%
fav_tweet_count_2022 = 0

for tweet_list in df["tweets"]:
    for tweet in tweet_list:
        if tweet["twt_date"][:2] == '22':
            fav_tweet_count_2022 += 1
            
print(f"Favorite tweet count for 2022: {fav_tweet_count_2022}")
# Out:
# Favorite tweet count for 2022: 3736420

# %% [markdown]
# ## Find Monthly Topics

# %%
# Turkish Stop Words
trstop = [
    'a', 'acaba', 'altı', 'altmış', 'ama', 'ancak', 'arada', 'artık', 'asla', 'aslında', 'aslında', 'ayrıca', 'az', 'bana',
    'bazen', 'bazı', 'bazıları', 'belki', 'ben', 'benden', 'beni', 'benim', 'beri', 'beş', 'bile', 'bilhassa', 'bin', 'bir',
    'biraz', 'birçoğu', 'birçok', 'biri', 'birisi', 'birkaç', 'birşey', 'biz', 'bizden', 'bize', 'bizi', 'bizim', 'böyle',
    'böylece', 'bu', 'buna', 'bunda', 'bundan', 'bunlar', 'bunları', 'bunların', 'bunu', 'bunun', 'burada', 'bütün', 'çoğu',
    'çoğunu', 'çok', 'çünkü', 'da', 'daha', 'dahi', 'dan', 'de', 'defa', 'değil', 'diğer', 'diğeri', 'diğerleri', 'diye',
    'doksan', 'dokuz', 'dolayı', 'dolayısıyla', 'dört', 'e', 'edecek', 'eden', 'ederek', 'edilecek', 'ediliyor', 'edilmesi',
    'ediyor', 'eğer', 'elbette', 'elli', 'en', 'etmesi', 'etti', 'ettiği', 'ettiğini', 'fakat', 'falan', 'filan', 'gene',
    'gereği', 'gerek', 'gibi', 'göre', 'hala', 'halde', 'halen', 'hangi', 'hangisi', 'hani', 'hatta', 'hem', 'henüz', 'hep',
    'hepsi', 'her', 'herhangi', 'herkes', 'herkese', 'herkesi', 'herkesin', 'hiç', 'hiçbir', 'hiçbiri', 'i', 'ı', 'için',
    'içinde', 'iki', 'ile', 'ilgili', 'ise', 'işte', 'itibaren', 'itibariyle', 'kaç', 'kadar', 'karşın', 'kendi', 'kendilerine',
    'kendine', 'kendini', 'kendisi', 'kendisine', 'kendisini', 'kez', 'ki', 'kim', 'kime', 'kimi', 'kimin', 'kimisi', 'kimse',
    'kırk', 'madem', 'mi', 'mı', 'milyar', 'milyon', 'mu', 'mü', 'nasıl', 'ne', 'neden', 'nedenle', 'nerde', 'nerede', 'nereye',
    'neyse', 'niçin', 'nin', 'nın', 'niye', 'nun', 'nün', 'o', 'öbür', 'olan', 'olarak', 'oldu', 'olduğu', 'olduğunu',
    'olduklarını', 'olmadı', 'olmadığı', 'olmak', 'olması', 'olmayan', 'olmaz', 'olsa', 'olsun', 'olup', 'olur', 'olur',
    'olursa', 'oluyor', 'on', 'ön', 'ona', 'önce', 'ondan', 'onlar', 'onlara', 'onlardan', 'onları', 'onların', 'onu', 'onun',
    'orada', 'öte', 'ötürü', 'otuz', 'öyle', 'oysa', 'pek', 'rağmen', 'sana', 'sanki', 'sanki', 'şayet', 'şekilde', 'sekiz',
    'seksen', 'sen', 'senden', 'seni', 'senin', 'şey', 'şeyden', 'şeye', 'şeyi', 'şeyler', 'şimdi', 'siz', 'siz', 'sizden',
    'sizden', 'size', 'sizi', 'sizi', 'sizin', 'sizin', 'sonra', 'şöyle', 'şu', 'şuna', 'şunları', 'şunu', 'ta', 'tabii',
    'tam', 'tamam', 'tamamen', 'tarafından', 'trilyon', 'tüm', 'tümü', 'u', 'ü', 'üç', 'un', 'ün', 'üzere', 'var', 'vardı',
    've', 'veya', 'ya', 'yani', 'yapacak', 'yapılan', 'yapılması', 'yapıyor', 'yapmak', 'yaptı', 'yaptığı', 'yaptığını',
    'yaptıkları', 'ye', 'yedi', 'yerine', 'yetmiş', 'yi', 'yı', 'yine', 'yirmi', 'yoksa', 'yu', 'yüz', 'zaten', 'zira'
] # https://github.com/ahmetax/trstop/blob/master/dosyalar/turkce-stop-words

nltk_trstop = [
    'acaba', 'ama', 'aslında', 'az', 'bazı', 'belki', 'biri', 'birkaç', 'birşey', 'biz', 'bu', 'çok', 'çünkü', 'da', 'daha',
    'de', 'defa', 'diye', 'eğer', 'en', 'gibi', 'hem', 'hep', 'hepsi', 'her', 'hiç', 'için', 'ile', 'ise', 'kez', 'ki', 'kim',
    'mı', 'mu', 'mü', 'nasıl', 'ne', 'neden', 'nerde', 'nerede', 'nereye', 'niçin', 'niye', 'o', 'sanki', 'şey', 'siz', 'şu',
    'tüm', 've', 'veya', 'ya', 'yani'
] # https://github.com/xiamx/node-nltk-stopwords/blob/master/data/stopwords/turkish

add_stop = [
    'a', 'b', 'c', 'ç', 'd', 'e', 'f', 'g', 'ğ', 'h', 'ı', 'i', 'j', 'k', 'l', 'm', 'n', 'o', 'ö', 'p', 'r', 's', 'ş', 't',
    'u', 'ü', 'v', 'y', 'z', 'li', 'lı', 'si', 'sı', 'te', 'ta', 'ın', 'in', 'na', 'ne', 'ler', 'lar', 'de', 'da', 'nın', 'nin',
    'lık', 'ım', 'im', 'yok', 'di', 'dı'
]

english_stop_words = stopwords.words('english')

stop_words = sorted(list(set(trstop).union(nltk_trstop).union(add_stop).union(english_stop_words)))

# %%
def monthly_tweets(year, month):
    
    tweets = []
    
    for tweet_list in df["tweets"]:
        for tweet in tweet_list:
            if tweet["twt_date"][:4] == str(year) + str(month):
                tweets.append(tweet["ref_twt_txt"])
    
    # Remove URLs
    tweets = [tweet[:re.search("http", tweet).start()] for tweet in tweets if "http" in tweet]
    # Convert to pandas Series
    tweets = pd.Series(tweets, name="tweets")
    # Lowercase Turkish letters
    tweets = tweets.apply(lambda x: x.replace("Ç", "ç").replace("Ğ", "ğ").replace("I", "ı").replace("İ", "i").replace("Ö", "ö").replace("Ş", "ş").replace("Ü", "ü"))
    # Lowercase all letters
    tweets = tweets.apply(lambda x: x.lower())
    # Replace newline characters ("\n") with space
    tweets = tweets.apply(lambda x: x.replace("\n", " "))
    # Replace non-letter characters with a space
    tweets = tweets.apply(lambda x: re.sub('[^A-Za-z#@çğıöşü]+',' ', x))
    # Stop word removal
    tweets = tweets.apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
    
    return tweets

# %%
def get_most_common_words_and_hashtags(year, month):
    
    tweets = monthly_tweets(str(year), str(month))
    
    words = []
    hashtags = []
    
    for tweet in tweets:
        for word in tweet.strip().split():
            if len(word) > 1:
                words.append(word)
            
            if word[0] == "#" and len(word) > 1:
                hashtags.append(word)
                
    return pd.concat([pd.Series([item[0] for item in Counter(words).most_common(200)], name=f"words_{year}{month}"), pd.Series([item[0] for item in Counter(hashtags).most_common(200)], name=f"hashtags_{year}{month}")], axis=1)

# %%
years = ["21", "22"]
months = ["01", "02", "03", "04", "05", "06", "07" ,"08", "09", "10", "11", "12"]

# %%
trends_df = pd.DataFrame()

for year in years:
    if year == "22":
        for month in months[:5]:
            print(f"Year: 20{year}, Month: {month} ...", end=" ")
            trends_df = pd.concat([trends_df, get_most_common_words_and_hashtags(year, month)], axis=1)
            print(f"completed!")
    else:
        for month in months:
            print(f"Year: 20{year}, Month: {month} ...", end=" ")
            trends_df = pd.concat([trends_df, get_most_common_words_and_hashtags(year, month)], axis=1)
            print(f"completed!")
# Out:
# Year: 2021, Month: 01 ... completed!
# Year: 2021, Month: 02 ... completed!
# Year: 2021, Month: 03 ... completed!
# Year: 2021, Month: 04 ... completed!
# Year: 2021, Month: 05 ... completed!
# Year: 2021, Month: 06 ... completed!
# Year: 2021, Month: 07 ... completed!
# Year: 2021, Month: 08 ... completed!
# Year: 2021, Month: 09 ... completed!
# Year: 2021, Month: 10 ... completed!
# Year: 2021, Month: 11 ... completed!
# Year: 2021, Month: 12 ... completed!
# Year: 2022, Month: 01 ... completed!
# Year: 2022, Month: 02 ... completed!
# Year: 2022, Month: 03 ... completed!
# Year: 2022, Month: 04 ... completed!
# Year: 2022, Month: 05 ... completed!

# %%
trends_df.head(60)
# Out:
#          words_2101               hashtags_2101                    words_2102  \
# 0             mesut               #armandasaklı                         büyük
# 1              özil             #fenersignmesut                    fenerbahçe
# 2        fenerbahçe                     #bjkvgs                           iyi
# 3              yeni            #yeniprofilresmi                         allah
# 4             büyük                   #survivor                           ilk
# 5               ilk             #hayirlicumalar                          yeni
# 6             bugün               #jummamubarak                         devam
# 7               iyi                  #gönüldağı                         şubat
# 8             güzel                    #bjkvriz                         bugün
# 9             devam                #galatasaray                       türkiye
# 10         istanbul                   #beşiktaş                      günaydın
# 11          türkiye          #beşiktaşınmaçıvar                         güzel
# 12    #armandasaklı           #aslangibisponsor                   galatasaray
# 13              son                   #whatsapp                           son
# 14             ocak           #bizfenerbahçeyiz                        rahmet
# 15      galatasaray                         #tb                            il
# 16            allah                     #bjkvts                        #fbvgs
# 17         günaydın                     #fbvank                   @fenerbahce
# 18              amp                #yagunnersya                        eğitim
# 19         teşekkür      #fenerbahcemesutoluyor                     taraftarı
# 20          hayırlı         #inandığınyoldayürü                          türk
# 21              gün                     #gfkvgs                         sayın
# 22               il                    #bjkvgöz                    başkanımız
# 23       başkanımız        #polisiminyanındayım                           gün
# 24         birlikte                      #gsvgb                            sn
# 25              yıl                  #ultraslan                      teşekkür
# 26  #fenersignmesut          #whatsappsiliyoruz                         zaman
# 27              tek                    #mesutol                  #galatasaray
# 28               sn               #washingtondc                         genel
# 29      @fenerbahce                      #trump                           amp
# 30         transfer                        #trt                           tan
# 31             türk                    #türksat                      istanbul
# 32        taraftarı  #bugüngünlerdengalatasaray                         şehit
# 33            sayın                 #fethisekin                           yıl
# 34            genel           #watsappsiliyoruz                           tek
# 35         beşiktaş                     #ymsvgs                      birlikte
# 36           sağlık           #bahçeşehirkoleji  #turkishstudentslivesmatters
# 37             günü                     #fbvkys                         iptal
# 38         ediyoruz                     #fbvriz                          maçı
# 39            zaman              #liderbeşiktaş                    @rterdogan
# 40           eğitim                   #istanbul                       hayırlı
# 41              hoş                    #htyvbjk                 #venividivici
# 42              new         #wehavegotmesutozil                           maç
# 43      teşekkürler                        #ucl                       başkanı
# 44             club                      #hedef                      ediyoruz
# 45             ilçe                    #kysvbjk                        ailesi
# 46              kar             #fenerinmaçıvar                          günü
# 47            dünya                   #telegram                          ilçe
# 48       @rterdogan                     #gsvdnz                 #armandasaklı
# 49           geldin              #menajerimiara                       gençlik
# 50           destek               #yellowlegacy                        sağlık
# 51             saat                 #kırmızıoda                        destek
# 52         futbolcu                     #ankara                         mesut
# 53         ediyorum   #yalnızdeğilsinfatihterim                     diliyorum
# 54              maç             #hayırlıcumalar                          saat
# 55           geçmiş                  #sondakika                        olacak
# 56    bilgilendirme          #masumlarapartmanı                        sadece
# 57            mutlu                #trabzonspor                            bi
# 58          başkanı                      #çukur   #turkishstudentslivesmatter
# 59          gelecek          #kabekutsalımızdır                       mostafa
#
#                     hashtags_2102                 words_2103  \
# 0                          #fbvgs                       mart
# 1                    #galatasaray                      büyük
# 2    #turkishstudentslivesmatters                      allah
# 3                   #venividivici                    türkiye
# 4                   #armandasaklı                        iyi
# 5     #turkishstudentslivesmatter                      güzel
# 6                      #yafenerya                      bugün
# 7            #erdoğanınyanındayız                      devam
# 8    #ertelemedeğiliptalistiyoruz                       yeni
# 9         #whosaveturkishstudents                       türk
# 10               #yeniprofilresmi                 başkanımız
# 11  #uefaturkishfootballcheckover                        ilk
# 12                   #neyapacağız                      kadın
# 13               #yaiptalyaistifa                 fenerbahçe
# 14                        #gsvksm                     rahmet
# 15                        #gsverz                   teşekkür
# 16                  #kahrolsunpkk                       günü
# 17                         #tsvfb                         il
# 18          #fıratyılmazçakıroğlu                      kutlu
# 19                #hayirlicumalar                      genel
# 20              #bizfenerbahçeyiz                      dünya
# 21                        #gsvbşk                      sayın
# 22                        #hatvfb                        gün
# 23     #bugüngünlerdengalatasaray                        yıl
# 24                     #ultraslan                         sn
# 25             #kıtalararasıderbi                   günaydın
# 26                        #alnvgs                      milli
# 27                       #bitcoin                        son
# 28                #uzmançavuşahak                        tek
# 29                 #kartalpençesi                   birlikte
# 30                  #sinavdayokuz                       ilçe
# 31                      #beşiktaş                   kadınlar
# 32                 #konsantrasyon                  çanakkale
# 33             #aşağıbakmayacağız                   istanbul
# 34                        #gbvbjk                    hayırlı
# 35            #inandığınyoldayürü                     sağlık
# 36                         #hedef                     eğitim
# 37    #equalityforturkishstudents                   ediyorum
# 38            #sorumlusukimolacak                   beşiktaş
# 39             #beşiktaşınmaçıvar                    ziyaret
# 40                        #fbvgoz                        amp
# 41                    #ziyaselcuk                      şehit
# 42                 #liselereiptal                  tebrikler
# 43                #fenerinmaçıvar                      zaman
# 44                           #ucl                    mustafa
# 45                #doğancüceloğlu                        tan
# 46      #iyikidoğdunmilletinadamı                    gençlik
# 47                        #fbvsgs                    başkanı
# 48                       #bjkvkon                         ak
# 49                     #gönüldağı                         bi
# 50                       #antvbjk              #armandasaklı
# 51                  #jummamubarak             #bizimçocuklar
# 52                       #bjkvdnz                       saat
# 53          #devletiminyanindayim                   ediyoruz
# 54               #countdowntomars                   anıyoruz
# 55            #gökyüzünebakayıgör                     kurulu
# 56                  #özgecanaslan  #öğrencilerölmekistemiyor
# 57              #bahçeşehirkoleji                    atatürk
# 58             #duybiziziyaselcuk                       maçı
# 59              #necmettinerbakan                      parti
#
#                   hashtags_2103     words_2104               hashtags_2104  \
# 0                 #armandasaklı          nisan               #armandasaklı
# 1                #bizimçocuklar          bugün            #yeniprofilresmi
# 2     #öğrencilerölmekistemiyor          güzel                    #bitcoin
# 3           #kadinasiddetehayir          allah                   #survivor
# 4              #yeniprofilresmi        türkiye                    #ramazan
# 5                       #bjkvfb          devam              #liderbeşiktaş
# 6        #noticeturkishstudents            iyi                #galatasaray
# 7                  #galatasaray            ilk           #aydınlanmayangün
# 8                     #beşiktaş           yeni          #beşiktaşınmaçıvar
# 9           #istanbulsözleşmesi           türk                 #tamkapanma
# 10     #ibrahimzaraptutuklansın          büyük                    #erzvbjk
# 11                       #dolar            gün                    #bjkvaly
# 12                      #bitlis          çocuk           #bizfenerbahçeyiz
# 13           #beşiktaşınmaçıvar          kutlu                     #htyvgs
# 14   #istanbulsozlesmesiyasatir        ramazan                    #rizvbjk
# 15          #kadınaşiddetehayır            yıl                     #gözvgs
# 16            #ziyaselcukistifa     başkanımız                  #gönüldağı
# 17          #inandığınyoldayürü            son                    #binance
# 18                      #kysvgs       teşekkür                        #btc
# 19            #muhsinyazıcıoğlu  #armandasaklı                #hodrimeydan
# 20                   #ultraslan          sayın          #hayırlıramazanlar
# 21                #rasimoztekin          zaman                      #sahur
# 22                    #survivor        hayırlı                     #antvgs
# 23                    #whatsapp             il                      #gsvkg
# 24             #mehmetakifersoy             sn  #bugüngünlerdengalatasaray
# 25  #türkiyeiçingüvenveistikrar       birlikte                   #beşiktaş
# 26                    #ibfkvbjk     fenerbahçe                     #alyvfb
# 27                    #bjkvibfk           maçı                    #bjkvhty
# 28                #beratkandili       beşiktaş                        #msu
# 29               #istiklalmarşı         ulusal                        #btt
# 30                         #wcq          genel      #milliteknolojihamlesi
# 31                      #ankvgs      egemenlik            #efsaneyaztarihe
# 32      #dünyabeşiktaşlılargünü            amp           #bahçeşehirkoleji
# 33                      #gsvçrs         rahmet                     #fbvkas
# 34                #müslümgürses            tek                    #sivvbjk
# 35              #gelecektarımda          dünya                    #bjkvkys
# 36      #heartheturkishstudents         eğitim                 #camdakikız
# 37                      #gsvdgs    galatasaray             #gelecektarımda
# 38            #kütüphanehaftası        başkanı                      #çukur
# 39                     #bjkvgfk           ilçe           #gençlerneistiyor
# 40                #rasimöztekin           günü              #süleymançakır
# 41                      #gsvriz       ediyoruz             #fenerinmaçıvar
# 42                     #bitcoin       istanbul             #haddinizibilin
# 43             #gençsinöndeyürü             bi         #satılmışalanyaspor
# 44           #çanakkalegeçilmez       günaydın                    #celasun
# 45      #türkiyeninengüzelşehri        mustafa            #alparslantürkeş
# 46     #iptalkararınıbekliyoruz       ediyorum                     #fbvdnz
# 47                #mhpmillettir        atatürk                   #teşkilat
# 48   #bugüngünlerdengalatasaray          milli             #hayırlıcumalar
# 49                   #gönüldağı         sağlık                    #bjkvank
# 50                      #nortur         sadece                    #tecavüz
# 51                     #ymsvbjk         destek                      #gsvts
# 52               #bizimcocuklar        gençlik                    #kasvbjk
# 53              #hayirlicumalar           saat           #bunasılkapanmaki
# 54               #mhptürkiyedir          mutlu                       #doge
# 55              #zkusagiunutmaz          kadın                     #akıncı
# 56                       #borsa        bayramı                     #ymsvfb
# 57   #istanbulsözleşmesiyaşatır            ali                    #ramadan
# 58               #istiklalmarsı          hafta                        #ucl
# 59                   #yasakelma         avrupa                 #kriptopara
#
#           words_2105                hashtags_2105  ...   words_2201  \
# 0           beşiktaş              #şampiyonsensin  ...          iyi
# 1              mayıs             #aksadabaskınvar  ...        güzel
# 2              allah                #armandasaklı  ...          ilk
# 3    #şampiyonsensin                 #mescidiaksa  ...        allah
# 4             israil                      #gsvbjk  ...          son
# 5           şampiyon             #aksadabaskinvar  ...         yeni
# 6              güzel                     #bjkvhty  ...        bugün
# 7                ilk                    #survivor  ...        devam
# 8            türkiye              #genocideingaza  ...        büyük
# 9                iyi               #freepalestine  ...      türkiye
# 10             kutlu                 #galatasaray  ...        ahmet
# 11             bugün             #gazaunderattack  ...         türk
# 12             devam                    #heargaza  ...           bi
# 13               son             #yeniprofilresmi  ...          kar
# 14             büyük            #sampiyonbesiktas  ...         ocak
# 15              yeni          #ikikupatekşampiyon  ...     istanbul
# 16  #aksadabaskınvar                     #gözvbjk  ...          amp
# 17               lig                  #sedatpeker  ...          yıl
# 18             kudüs                  #hopetogaza  ...          tek
# 19               gün                     #bitcoin  ...  galatasaray
# 20              türk            #şampiyonbeşiktaş  ...          gün
# 21       galatasaray           #alaqsaunderattack  ...     teşekkür
# 22             süper              #ramazanbayramı  ...        çalık
# 23            tebrik                       #kudüs  ...       rahmet
# 24               yıl                      #dnzvgs  ...        zaman
# 25          istanbul                 #annelergünü  ...           il
# 26     #armandasaklı                      #israil  ...       eğitim
# 27              günü                    #beşiktaş  ...        sayın
# 28           atatürk                   #palestine  ...   başkanımız
# 29      #mescidiaksa                     #telaviv  ...        genel
# 30              spor            #gazzaunderattack  ...     birlikte
# 31         şampiyonu                     #bjkvfkg  ...         günü
# 32               amp           #beşiktaşınmaçıvar  ...       sadece
# 33           gençlik                       #gazze  ...           sn
# 34             dünya              #adanademirspor  ...          tan
# 35        başkanımız                      #gsvyms  ...          new
# 36          filistin                 #kadirgecesi  ...  #ahmetçalık
# 37          ediyorum                    #filistin  ...         gece
# 38               tek                  #eidmubarak  ...        fatih
# 39             zaman   #bugüngünlerdengalatasaray  ...        insan
# 40              aksa            #savesheikhjarrah  ...         saat
# 41       şampiyonluk                        #gaza  ...          yer
# 42            sezonu            #ısraeliterrorism  ...        video
# 43          teşekkür                           #f  ...        gelen
# 44            destek                    #besiktas  ...      başkanı
# 45          günaydın               #milletinadamı  ...      ziyaret
# 46          birlikte                       #çukur  ...    konyaspor
# 47                bi               #liderbeşiktaş  ...     beşiktaş
# 48             genel                         #btc  ...           tl
# 49            sadece               #savepalestine  ...     günaydın
# 50          çocuklar                     #antvbjk  ...      hayırlı
# 51               den              #helaletmiyorum  ...        imzam
# 52                sn                         #bts  ...     ediyorum
# 53               maç      #vurpençenişampiyonluğa  ...         ilçe
# 54           hayırlı        #cometotrabzonsörloth  ...         adam
# 55           #gsvbjk                 #meşalebende  ...          den
# 56         @besiktas                      #ankvfb  ...       cennet
# 57             sayın  #soscolombianosestanmatando  ...        milli
# 58            sergen                   #ultraslan  ...     ediyoruz
# 59             fatih                      #efsane  ...        kadın
#
#                     hashtags_2201   words_2202             hashtags_2202  \
# 0                     #ahmetçalık        güzel                   #samsun
# 1                #yeniprofilresmi          iyi          #yeniprofilresmi
# 2                        #bitcoin        bugün                 #survivor
# 3                              #z        allah                  #ukrania
# 4                 #boğazınkartalı      türkiye           #boğazınkartalı
# 5                       #survivor      ukrayna                  #ukrayna
# 6                            #btc          ilk                  #ukraina
# 7                            #nft        şubat            #ukrainerussia
# 8            #sezenaksuhaddinibil        devam                     #kiew
# 9                #survivorallstar        büyük                  #ukraine
# 10                   #galatasaray         yeni              #galatasaray
# 11                      #eneskara          son          #survivorallstar
# 12                          #ıbax         türk                #ukrainian
# 13                    #fatihterim          yıl                #zelenskiy
# 14                    #fatmagirik           il                 #zelensky
# 15             #beşiktaşınmaçıvar          gün                  #stopwar
# 16                     #metaverse          amp                    #putin
# 17                         #hcafc     teşekkür                     #kiev
# 18                          #togg        sayın              #sılaşentürk
# 19                #imamoğluistifa   başkanımız              #savaşahayır
# 20                #maskekimsinsen        genel             #ukraynarusya
# 21                       #airdrop     birlikte                  #bitcoin
# 22                     #ultraslan        dünya         #ukrainerussiawar
# 23                        #htyvgs          tek                      #yks
# 24                         #gsvts      atatürk                #sondakika
# 25                       #binance           bi                      #uel
# 26                           #ucl           sn                 #worldwar
# 27                        #deprem        zaman        #beşiktaşınmaçıvar
# 28                         #yargı  galatasaray       #ukraineunderattack
# 29                        #sigara        rusya     #fıratyılmazçakıroğlu
# 30                       #bjkvant       eğitim                      #nft
# 31                       #fkgvbjk         ilçe               #stoprussia
# 32                       #rizvbjk         günü                   #gsvriz
# 33     #bugüngünlerdengalatasaray      başkanı                   #gözvgs
# 34                      #istanbul       sadece              #savasahayır
# 35                           #kar     beşiktaş                   #russia
# 36  #kabinedenonlineheryeromicron     ediyorum                #stopputin
# 37              #bahçeşehirkoleji     istanbul                  #sivvbjk
# 38                             #f        savaş                  #moskova
# 39                       #somalia      ziyaret                      #psl
# 40                 #newprofilepic         adam      #mustafakemalatatürk
# 41                     #gaziantep      hayırlı                  #bjkvgöz
# 42                    #karyağıyor          den  #soemestrtatiliuzatılsın
# 43                           #uel        insan                        #l
# 44                    #fethisekin   fenerbahçe            #regaipkandili
# 45                     #gönüldağı        karşı                      #btc
# 46                          #bist      mübarek                    #nowar
# 47                           #tbt     ediyoruz            #newprofilepic
# 48                       #göztepe        kadın           #sevgililergünü
# 49              #burakelmasistifa         saat             #migrosboykot
# 50                          #nfts           dr                #sondakıka
# 51                       #ymsvbjk     günaydın                    #rusya
# 52                     #tuzyoktuz          rus             #ultraslanunı
# 53                       #bjkvgfk         aynı             #miraçkandili
# 54                           #ces       rahmet              #allahuakbar
# 55               #iyikivarsıneren      mustafa     #ukraynanınyanındayız
# 56                             #l        kemal                #ultraslan
# 57                #hayırlıcumalar       cennet                  #bjkvalt
# 58                       #roadtof         geri                 #beşiktaş
# 59                #adanademirspor        putin         #necmettinerbakan
#
#      words_2203                hashtags_2203   words_2204  \
# 0         güzel                         #uel        nisan
# 1          mart                      #gsvbjk          iyi
# 2           iyi                    #survivor        güzel
# 3         allah             #yeniprofilresmi        bugün
# 4         bugün                    #gsvbarça        allah
# 5       türkiye                 #galatasaray          ilk
# 6   galatasaray                     #pakvaus         türk
# 7           ilk                    #barçavgs        büyük
# 8           amp              #boğazınkartalı      türkiye
# 9         büyük                   #gönüldağı          son
# 10        dünya           #çanakkalegeçilmez   fenerbahçe
# 11        devam                     #bitcoin        çocuk
# 12         günü       #milliteknolojihamlesi        devam
# 13         türk                #beratkandili   başkanımız
# 14          son   #bugüngünlerdengalatasaray           bi
# 15         yeni            #muhsinyazıcıoğlu        iftar
# 16   başkanımız               #newprofilepic          yıl
# 17          gün             #survivorallstar          gün
# 18     teşekkür                    #barcavgs         yeni
# 19           il                    #pakistan      ramazan
# 20        sayın                           #m     birlikte
# 21           sn           #beşiktaşınmaçıvar  trabzonspor
# 22          yıl                         #msü     teşekkür
# 23        genel  #vatanbizeemanetcanımızkime           il
# 24           bi                   #ultraslan          tek
# 25          tek                         #nft     beşiktaş
# 26        kutlu                         #btc        kutlu
# 27     istanbul                           #f        genel
# 28         #uel               #adanaemniyeti  galatasaray
# 29    çanakkale                      #akıncı           sn
# 30     beşiktaş                     #ukraine      hayırlı
# 31        kadın             #mehmetakifersoy        zaman
# 32         ilçe                    #istanbul        sayın
# 33        zaman                #ultraslanunı     istanbul
# 34     birlikte            #behindyouskipper         ilçe
# 35      ziyaret               #oıcınpakistan         günü
# 36        milli               #boysreadyhain       ulusal
# 37      hayırlı                 #pakistanday    egemenlik
# 38      başkanı                #insandediğin          amp
# 39        insan           #canakkalegecilmez       sadece
# 40       sadece          #çeyrekfinalyolunda         maçı
# 41       eğitim                 #bubirişaret        dünya
# 42       rahmet                   #sondakika          lig
# 43     kadınlar               #istiklalmarşı        insan
# 44     ediyorum                       #rıfat     günaydın
# 45      #gsvbjk                     #binance        şehit
# 46   fenerbahçe                   #bahraingp      bayramı
# 47    barcelona                    #gsvbarca      atatürk
# 48     pakistan                         #ucl        akşam
# 49     ediyoruz                         #oıc       rahmet
# 50     günaydın                   #kızılelma        geldi
# 51         saat                #ıamımrankhan      başkanı
# 52      atatürk                           #l      mübarek
# 53          day         #suriyelipolisolamaz        kadın
# 54       devlet                    #beşiktaş          bak
# 55       avrupa                      #tsvbjk         gece
# 56        gelen                   #metaverse      ziyaret
# 57      mustafa                     #somalia         adam
# 58          maç                    #bjkvibfk     ediyorum
# 59        geldi                       #gsbgm      gençlik
#
#                  hashtags_2204         words_2205             hashtags_2205
# 0                     #ramazan              mayıs         #inadıylaşampiyon
# 1              #boğazınkartalı         fenerbahçe           #ramazanbayramı
# 2             #yeniprofilresmi                iyi                   #bjkvfb
# 3                       #fbvgs              güzel                 #survivor
# 4                    #survivor               türk              #annelergünü
# 5             #survivorallstar        trabzonspor              #trabzonspor
# 6                 #galatasaray            türkiye          #yeniprofilresmi
# 7                 #kadirgecesi              bugün           #boğazınkartalı
# 8                        #şamp              kutlu                   #efsane
# 9                     #bjkvaly              büyük             #sessizistila
# 10          #beşiktaşınmaçıvar             bayram          #survivorallstar
# 11              #süleymançakır              allah                      #ucl
# 12                    #bjkvkas                ilk                 #yenikapı
# 13                    #grsvbjk               günü              #galatasaray
# 14                    #bitcoin                 bi               #eidmubarak
# 15                     #altvgs           istanbul                  #bitcoin
# 16        #sampiyontrabzonspor                son                  #gözvbjk
# 17                     #rizvfb           şampiyon                  #trabzon
# 18  #bugüngünlerdengalatasaray              devam                #ultraslan
# 19                  #gönüldağı                tek                      #btc
# 20                     #gsvyms           beşiktaş                  #ıbfkvgs
# 21                        #btc               yeni        #beşiktaşınmaçıvar
# 22           #inadıylaşampiyon                yıl               #melissezen
# 23        #şampiyontrabzonspor                gün                        #f
# 24                     #tsvbjk         başkanımız                  #kysvbjk
# 25                        #ucl            ramazan                   #kürtçe
# 26                #trabzonspor        şampiyonluk                  #metgala
# 27                     #fbvgfk           birlikte                   #gsvads
# 28                  #sondakika            atatürk                  #ramazan
# 29                     #iftara              zaman               #beınsports
# 30                  #ultraslan              dünya         #mondaymotivation
# 31                          #f                ali          #championsleague
# 32                        #nft              genel  #alparslanhocayaözgürlük
# 33     #gözümüzkulağımızaksada              sayın      #sampiyontrabzonspor
# 34                    #pegasus               spor               #eurovision
# 35                     #fbvsgs        galatasaray                  #miamigp
# 36             #fenerinmaçıvar                 il                 #günaydın
# 37                    #kysvbjk           teşekkür            #doctorstrange
# 38                     #tsvant                amp                #sondakika
# 39                   #beşiktaş              mutlu                   #gsvsvs
# 40                      #sahur             sadece                 #beşiktaş
# 41                    #ramadan  #inadıylaşampiyon         #survivoralllstar
# 42           #freeahmadmanasra           günaydın                    #mayıs
# 43                     #gsvsvs            trabzon      #şampiyontrabzonspor
# 44             #hayırlıcumalar              kadın             #zaferpartisi
# 45            #beşiktaşhentbol                 sn       #şampiyonankaragücü
# 46                     #fbvgöz              ahmet                      #nft
# 47                      #iftar              geldi               #ankaragücü
# 48                #mescidiaksa               adam  #birdireniştirfenerbahçe
# 49                 #pençekilit            başkanı                   #aporla
# 50                #parkedeekol            hayırlı                   #htyvts
# 51       #şampiyonlarasaygıyla              süper           #hayırlıcumalar
# 52                   #suriyeli                yer                #bursaspor
# 53                   #günaydın                koç           #fenerinmaçıvar
# 54                        #tbt            bayramı                     #soma
# 55                  #metaverse          bayramlar       #atatürküsevmiyorum
# 56          #hayırlıramazanlar                lig     #rizeartvinhavalimanı
# 57          #geziyisavunuyoruz               maçı             #iyibayramlar
# 58   #marchagainstımportedgovt            yaşında               #hıdırellez
# 59               #ultraslanunı            mübarek               #fenerbahçe
#
# [60 rows x 34 columns]

# %%
trends_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   words_2101     200 non-null    object
#  1   hashtags_2101  200 non-null    object
#  2   words_2102     200 non-null    object
#  3   hashtags_2102  200 non-null    object
#  4   words_2103     200 non-null    object
#  5   hashtags_2103  200 non-null    object
#  6   words_2104     200 non-null    object
#  7   hashtags_2104  200 non-null    object
#  8   words_2105     200 non-null    object
#  9   hashtags_2105  200 non-null    object
#  10  words_2106     200 non-null    object
#  11  hashtags_2106  200 non-null    object
#  12  words_2107     200 non-null    object
#  13  hashtags_2107  200 non-null    object
#  14  words_2108     200 non-null    object
#  15  hashtags_2108  200 non-null    object
#  16  words_2109     200 non-null    object
#  17  hashtags_2109  200 non-null    object
#  18  words_2110     200 non-null    object
#  19  hashtags_2110  200 non-null    object
#  20  words_2111     200 non-null    object
#  21  hashtags_2111  200 non-null    object
#  22  words_2112     200 non-null    object
#  23  hashtags_2112  200 non-null    object
#  24  words_2201     200 non-null    object
#  25  hashtags_2201  200 non-null    object
#  26  words_2202     200 non-null    object
#  27  hashtags_2202  200 non-null    object
#  28  words_2203     200 non-null    object
#  29  hashtags_2203  200 non-null    object
#  30  words_2204     200 non-null    object
#  31  hashtags_2204  200 non-null    object
#  32  words_2205     200 non-null    object
#  33  hashtags_2205  200 non-null    object
# dtypes: object(34)
# memory usage: 53.2+ KB

# %%
trends_df.to_excel("twitter_trends.xlsx", index=False)
